# %% [markdown]
# On importe tout d'abord des libraires python utiles.

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow import keras

# %% [markdown]
# Nous allons charger le jeu de données iris. Ce jeu contient 150 données possédant 4 attributs et 3 classes distinctes.

# %%
iris = datasets.load_iris()

# %% [markdown]
# Récupérons les données et les classes respectivement:

# %%
X = iris.data
Y = iris.target

# %% [markdown]
# Regardons de plus près le format du jeu de données:

# %%
print(X.shape)
print(Y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# Comme nous pouvons le constater, le jeu de données possède 4 attributs comme prévu. Cependant, il semble que le vecteur de classes soit unidimensionnel.
#
# Etant donné que nous avons 3 classes différentes, l'idéal serait d'avoir 3 neurones dans la sortie du réseau de neurones. Il faut donc vectoriser $Y$ en utilisant un one-hot encoder.

# %%
Y = Y.reshape(-1,1) # Reshape to use the one hot encoder: it needs to be two dimensional
print(Y.shape)
enc = OneHotEncoder() # One hot encoder to vectorize the classes
Y = enc.fit_transform(Y).toarray()
print("Mapped output classes:")
print(enc.categories_)
print("New label shape:")
print(Y.shape)
# Out:
# (150, 1)
# Mapped output classes:
# [array([0, 1, 2])]
# New label shape:
# (150, 3)

# %% [markdown]
# L'encodeur a transformé $Y$ en une liste de vecteurs tel que tous les coefficients sont nuls sauf un qui vaut 1. "enc.categories_" montre la liste des classes avant transformation: $0,1$ or $2$. L'encodeur a attribué à ces classes les vecteurs $(1,0,0)$, $(0,1,0)$ and $(0,0,1)$ respectivement.
#
# Cela va donc nous aider a construire un réseau de neurones avec 3 neurones en sortie: le premier va s'activer pour la classe $0$, le second pour la classe $1$ et le dernier pour la classe $2$.
#
# Le vecteur "one-hot" peut être interpreté comme une distribution de probabilités: lorsque la valeur du label vaut $(1,0,0)$, cela veut dire que la probabilité de la classe $0$ est 1, et celle des deux autres est nulle.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1) # Split train and test set randomly with 75% and 25% proportion respectively
print(X_train.shape)
# Out:
# (112, 4)

# %% [markdown]
# On divise le jeu de données pour l'entraînement et le test, avec comme proportions respectives 75\% et 25\%.

# %%
def create_model():
    '''
    Create a fully connected neural network with one input layer, one hidden layer and one output layer with softmax activation.
    '''
    input_layer = keras.layers.Input(shape=(4,)) # Input layer
    h = keras.layers.Dense(128)(input_layer) # Hidden layer
    h = keras.layers.Dense(3, activation='softmax')(h) # Output layer
    model = keras.models.Model(inputs=input_layer, outputs=h)
    return model

# %% [markdown]
# Nous définissons désormais l'architecture du réseau de neurones. Le réseau ci-présent possède une couche d'entrée, une couche cachée et une couche de sortie.
#
# La première couche est la couche d'entrée, qui a besoin d'une "shape" qui correspond au nombre de neurones en entrées, donc qui doit correspondre au nombre d'attributs de notre jeu de données. Ici nous avons 4 attributs donc 4 neurones en entrée.
#
# La seconde couche est la couche cachée intermédiaire, qui possède 128 neurones.
#
# La troisième couche est la couche de sortie, qui possède 3 neurones correspondant aux classes de sorties. La fonction d'activation "softmax" normalise les neurones $(x_{2,i})_{i=0}^2$ en sortie de telle sorte qu'ils représente une distribution de probabilité: $\forall x_{2,i}, 0 \leq x_{2,i} \leq 1$ and $\sum_i x_{2,i} = 1$.
#
# Plus précisément, $$softmax(x)_i =\frac{e^{x_i}}{\sum_j e^{x_j}}$$

# %%
model = create_model() # We create the model
model.compile(optimizer=keras.optimizers.SGD(lr=1e-2), loss='categorical_crossentropy', metrics=['accuracy']) # Compile the model: define optimizer, loss and eventual metrics

# %% [markdown]
# Une fois le modèle crée, il faut le compiler en définissant plusieurs paramètres:
#
# Un optimiseur qui définit la méthode d'optimisation du réseau. Ici on choisit l'optimiseur SGD (pour Stochastic Gradient Descent), qui correspond à la descente de gradient par batch. L'adjectif "stochastique" réfère à un aspect aléatoire, non-déterministe. C'est parce qu'on calcule le gradient sur un "batch" (un "paquet") aléatoire de données à chaque fois et non pas le jeu de données complet. Cela permet un calcul approximatif mais plus rapide de l'algorithme. D'autres méthodes d'optimisation existent, telles que des méthodes qui calculent un learning rate de manière adaptive (Adam), mais ce n'est pas l'objectif de cet exemple...
#
# L'argument "lr" correspond au learning rate, qui peut s'interpréter comme le pas dans la descente de gradient. Il s'agit du coefficient $\eta$ dans l'équation de mise à jour des poids: $w \leftarrow w - \eta \triangledown E[w]$. Un learning rate plus petit permet un apprentissage plus fin et précis mais également plus long.
#
# Le paramètre "loss" définit la fonction d'erreur que le réseau va chercher à minimiser. Ici, on utilise la loss entropie croisée catégorique, définie de la manière suivante:
#
# $$E(z)=-\sum_{i=0}^2 y_i \log(z_i)$$
#
# Ou $z$ est la sortie du réseau (après softmax), et $y$ le vecteur one-hot du jeu de données que le réseau devrait prédire. Par exemple, si la vraie classe à prédire est $2$, $y=(0,0,1)$ et alors $E(z)=-\log(z_2)$ et donc le réseau va chercher à maximiser $z_2$, soit le neurone correspondant à la classe $2$. Comme on a normalisé les neurones en sortie, cela va correspondre à minimiser $z_0$ et $z_1$.
#
# L'entropie croisée entre deux distributions $p$ et $q$ peut s'interpréter comme un degré d'incertitude entre les deux distributions: plus elle est élevée, moins il y a d'information commune entre les deux distributions. Lorsqu'elle est minimale, les deux distributions sont identiques, c'est pourquoi la méthode d'optimisation de l'entropie croisée est souvent utilisée lorsqu'on veut faire correspondre deux distributions de probabilités comme c'est notre cas ici.
#
# Le dernier paramètre, "metrics" permet d'ajouter des métriques à enregistrer pendant l'entraînement. Ici on a ajouté "accuracy" pour mesurer la précision de notre modèle durant son entraînement.

# %%
model_history = model.fit(X_train,Y_train,
                          batch_size=16,
                          epochs=250,
                          validation_data=(X_test,Y_test))
# Out:
# Epoch 1/250
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0774 - accuracy: 0.4196 - val_loss: 0.9639 - val_accuracy: 0.5789
# Epoch 2/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8799 - accuracy: 0.6696 - val_loss: 0.8750 - val_accuracy: 0.5789
# Epoch 3/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8021 - accuracy: 0.6696 - val_loss: 0.7713 - val_accuracy: 0.5789
# Epoch 4/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7803 - accuracy: 0.7054 - val_loss: 0.7485 - val_accuracy: 0.5789
# Epoch 5/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7740 - accuracy: 0.6607 - val_loss: 0.7405 - val_accuracy: 0.5789
# Epoch 6/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.7411 - val_loss: 0.6289 - val_accuracy: 0.8158
# Epoch 7/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6150 - accuracy: 0.7679 - val_loss: 0.6138 - val_accuracy: 0.6053
# Epoch 8/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6166 - accuracy: 0.7054 - val_loss: 0.5677 - val_accuracy: 0.7632
# Epoch 9/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5714 - accuracy: 0.7500 - val_loss: 0.5630 - val_accuracy: 0.8158
# Epoch 10/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5483 - accuracy: 0.8125 - val_loss: 0.6101 - val_accuracy: 0.5789
# Epoch 11/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 0.7054 - val_loss: 0.5171 - val_accuracy: 0.7895
# Epoch 12/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.7500 - val_loss: 0.5604 - val_accuracy: 0.6053
# Epoch 13/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5200 - accuracy: 0.7589 - val_loss: 0.5347 - val_accuracy: 0.6053
# Epoch 14/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7946 - val_loss: 0.4884 - val_accuracy: 1.0000
# Epoch 15/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4871 - accuracy: 0.8571 - val_loss: 0.5949 - val_accuracy: 0.5789
# Epoch 16/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4703 - accuracy: 0.7768 - val_loss: 0.4868 - val_accuracy: 0.7368
# Epoch 17/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4572 - accuracy: 0.8839 - val_loss: 0.4730 - val_accuracy: 0.8947
# Epoch 18/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8661 - val_loss: 0.5494 - val_accuracy: 0.6053
# Epoch 19/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.8214 - val_loss: 0.5029 - val_accuracy: 0.6053
# Epoch 20/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.8036 - val_loss: 0.6477 - val_accuracy: 0.5789
# Epoch 21/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4580 - accuracy: 0.7857 - val_loss: 0.4367 - val_accuracy: 0.9737
# Epoch 22/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4265 - accuracy: 0.8750 - val_loss: 0.4646 - val_accuracy: 0.7105
# Epoch 23/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8929 - val_loss: 0.6201 - val_accuracy: 0.5789
# Epoch 24/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.7946 - val_loss: 0.4194 - val_accuracy: 0.9737
# Epoch 25/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8571 - val_loss: 0.4457 - val_accuracy: 0.7368
# Epoch 26/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.9018 - val_loss: 0.4493 - val_accuracy: 0.7368
# Epoch 27/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3939 - accuracy: 0.8929 - val_loss: 0.4562 - val_accuracy: 0.6842
# Epoch 28/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8661 - val_loss: 0.3964 - val_accuracy: 0.9737
# Epoch 29/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.9196 - val_loss: 0.4134 - val_accuracy: 0.8421
# Epoch 30/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.9196 - val_loss: 0.4198 - val_accuracy: 0.7368
# Epoch 31/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3777 - accuracy: 0.9018 - val_loss: 0.3959 - val_accuracy: 0.8947
# Epoch 32/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.9107 - val_loss: 0.3686 - val_accuracy: 0.9211
# Epoch 33/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.9464 - val_loss: 0.4577 - val_accuracy: 0.6842
# Epoch 34/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8839 - val_loss: 0.3667 - val_accuracy: 0.9737
# Epoch 35/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3455 - accuracy: 0.9554 - val_loss: 0.3933 - val_accuracy: 0.8421
# Epoch 36/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.9375 - val_loss: 0.3882 - val_accuracy: 0.8684
# Epoch 37/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.8839 - val_loss: 0.3607 - val_accuracy: 0.8158
# Epoch 38/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3658 - accuracy: 0.9196 - val_loss: 0.4099 - val_accuracy: 0.7368
# Epoch 39/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3319 - accuracy: 0.9286 - val_loss: 0.3647 - val_accuracy: 0.8947
# Epoch 40/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.9375 - val_loss: 0.3369 - val_accuracy: 0.9211
# Epoch 41/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.9196 - val_loss: 0.3576 - val_accuracy: 0.8947
# Epoch 42/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.9464 - val_loss: 0.3689 - val_accuracy: 0.8684
# Epoch 43/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.9643 - val_loss: 0.4659 - val_accuracy: 0.6316
# Epoch 44/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.9196 - val_loss: 0.3967 - val_accuracy: 0.7368
# Epoch 45/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3016 - accuracy: 0.9375 - val_loss: 0.3670 - val_accuracy: 0.8684
# Epoch 46/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3138 - accuracy: 0.9107 - val_loss: 0.3482 - val_accuracy: 0.8947
# Epoch 47/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3000 - accuracy: 0.9464 - val_loss: 0.3674 - val_accuracy: 0.8421
# Epoch 48/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2988 - accuracy: 0.9375 - val_loss: 0.3143 - val_accuracy: 0.9737
# Epoch 49/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3088 - accuracy: 0.9464 - val_loss: 0.3624 - val_accuracy: 0.8421
# Epoch 50/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2878 - accuracy: 0.9196 - val_loss: 0.3040 - val_accuracy: 0.9474
# Epoch 51/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2875 - accuracy: 0.9643 - val_loss: 0.3658 - val_accuracy: 0.7368
# Epoch 52/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.9554 - val_loss: 0.3060 - val_accuracy: 0.9737
# Epoch 53/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2890 - accuracy: 0.9554 - val_loss: 0.3010 - val_accuracy: 0.9737
# Epoch 54/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.9286 - val_loss: 0.3659 - val_accuracy: 0.7368
# Epoch 55/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.9554 - val_loss: 0.3011 - val_accuracy: 0.9737
# Epoch 56/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.9375 - val_loss: 0.3041 - val_accuracy: 0.9474
# Epoch 57/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2920 - accuracy: 0.9107 - val_loss: 0.3045 - val_accuracy: 0.9474
# Epoch 58/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.9464 - val_loss: 0.3315 - val_accuracy: 0.8947
# Epoch 59/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.9375 - val_loss: 0.2989 - val_accuracy: 0.9474
# Epoch 60/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.9464 - val_loss: 0.2961 - val_accuracy: 0.9474
# Epoch 61/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2638 - accuracy: 0.9554 - val_loss: 0.3207 - val_accuracy: 0.8947
# Epoch 62/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.9554 - val_loss: 0.2753 - val_accuracy: 1.0000
# Epoch 63/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.9643 - val_loss: 0.3031 - val_accuracy: 0.8947
# Epoch 64/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2473 - accuracy: 0.9732 - val_loss: 0.2687 - val_accuracy: 0.9737
# Epoch 65/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.9821 - val_loss: 0.3563 - val_accuracy: 0.7368
# Epoch 66/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.9554 - val_loss: 0.2819 - val_accuracy: 0.9474
# Epoch 67/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.9643 - val_loss: 0.3146 - val_accuracy: 0.8947
# Epoch 68/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2431 - accuracy: 0.9732 - val_loss: 0.2756 - val_accuracy: 0.9474
# Epoch 69/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9732 - val_loss: 0.2585 - val_accuracy: 0.9737
# Epoch 70/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2610 - accuracy: 0.9464 - val_loss: 0.4115 - val_accuracy: 0.7368
# Epoch 71/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9464 - val_loss: 0.2571 - val_accuracy: 0.9737
# Epoch 72/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9643 - val_loss: 0.2626 - val_accuracy: 0.9737
# Epoch 73/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.9643 - val_loss: 0.2563 - val_accuracy: 0.9737
# Epoch 74/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2307 - accuracy: 0.9464 - val_loss: 0.2543 - val_accuracy: 0.9737
# Epoch 75/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9286 - val_loss: 0.2459 - val_accuracy: 0.9737
# Epoch 76/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9554 - val_loss: 0.2533 - val_accuracy: 0.9737
# Epoch 77/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2215 - accuracy: 0.9643 - val_loss: 0.2899 - val_accuracy: 0.8947
# Epoch 78/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9375 - val_loss: 0.2452 - val_accuracy: 0.9737
# Epoch 79/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9554 - val_loss: 0.2876 - val_accuracy: 0.8947
# Epoch 80/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2120 - accuracy: 0.9554 - val_loss: 0.3346 - val_accuracy: 0.7368
# Epoch 81/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9643 - val_loss: 0.2401 - val_accuracy: 0.9737
# Epoch 82/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9732 - val_loss: 0.2330 - val_accuracy: 0.9737
# Epoch 83/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2108 - accuracy: 0.9643 - val_loss: 0.2533 - val_accuracy: 0.9474
# Epoch 84/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2092 - accuracy: 0.9643 - val_loss: 0.2472 - val_accuracy: 0.9474
# Epoch 85/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2120 - accuracy: 0.9554 - val_loss: 0.2537 - val_accuracy: 0.9474
# Epoch 86/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2006 - accuracy: 0.9732 - val_loss: 0.2569 - val_accuracy: 0.9474
# Epoch 87/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.9643 - val_loss: 0.2953 - val_accuracy: 0.8684
# Epoch 88/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.9821 - val_loss: 0.2313 - val_accuracy: 0.9737
# Epoch 89/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9643 - val_loss: 0.2547 - val_accuracy: 0.9474
# Epoch 90/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2027 - accuracy: 0.9464 - val_loss: 0.2465 - val_accuracy: 0.9474
# Epoch 91/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9643 - val_loss: 0.2457 - val_accuracy: 0.9474
# Epoch 92/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9732 - val_loss: 0.2538 - val_accuracy: 0.9474
# Epoch 93/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9643 - val_loss: 0.2256 - val_accuracy: 0.9737
# Epoch 94/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9821 - val_loss: 0.2155 - val_accuracy: 1.0000
# Epoch 95/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.9643 - val_loss: 0.2328 - val_accuracy: 0.9474
# Epoch 96/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1889 - accuracy: 0.9732 - val_loss: 0.2642 - val_accuracy: 0.8947
# Epoch 97/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9554 - val_loss: 0.2241 - val_accuracy: 0.9737
# Epoch 98/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9732 - val_loss: 0.2101 - val_accuracy: 0.9474
# Epoch 99/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.9554 - val_loss: 0.2095 - val_accuracy: 1.0000
# Epoch 100/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1979 - accuracy: 0.9732 - val_loss: 0.2066 - val_accuracy: 0.9737
# Epoch 101/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.9554 - val_loss: 0.2446 - val_accuracy: 0.9474
# Epoch 102/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9643 - val_loss: 0.2117 - val_accuracy: 0.9737
# Epoch 103/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1781 - accuracy: 0.9643 - val_loss: 0.2032 - val_accuracy: 1.0000
# Epoch 104/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9732 - val_loss: 0.2492 - val_accuracy: 0.8947
# Epoch 105/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9643 - val_loss: 0.2429 - val_accuracy: 0.9474
# Epoch 106/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1840 - accuracy: 0.9643 - val_loss: 0.2516 - val_accuracy: 0.8947
# Epoch 107/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9732 - val_loss: 0.2459 - val_accuracy: 0.8947
# Epoch 108/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1763 - accuracy: 0.9821 - val_loss: 0.2443 - val_accuracy: 0.8947
# Epoch 109/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.9732 - val_loss: 0.2254 - val_accuracy: 0.9474
# Epoch 110/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9643 - val_loss: 0.2404 - val_accuracy: 0.9211
# Epoch 111/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1699 - accuracy: 0.9554 - val_loss: 0.2015 - val_accuracy: 0.9737
# Epoch 112/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9732 - val_loss: 0.2309 - val_accuracy: 0.9474
# Epoch 113/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1680 - accuracy: 0.9732 - val_loss: 0.2026 - val_accuracy: 0.9737
# Epoch 114/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.9643 - val_loss: 0.1907 - val_accuracy: 1.0000
# Epoch 115/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1690 - accuracy: 0.9732 - val_loss: 0.1961 - val_accuracy: 0.9737
# Epoch 116/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9732 - val_loss: 0.1941 - val_accuracy: 0.9737
# Epoch 117/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9732 - val_loss: 0.1923 - val_accuracy: 0.9737
# Epoch 118/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9643 - val_loss: 0.1870 - val_accuracy: 1.0000
# Epoch 119/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.9821 - val_loss: 0.1923 - val_accuracy: 0.9737
# Epoch 120/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1650 - accuracy: 0.9732 - val_loss: 0.2089 - val_accuracy: 0.9474
# Epoch 121/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9643 - val_loss: 0.1850 - val_accuracy: 0.9737
# Epoch 122/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1682 - accuracy: 0.9554 - val_loss: 0.2049 - val_accuracy: 0.9474
# Epoch 123/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1646 - accuracy: 0.9643 - val_loss: 0.2116 - val_accuracy: 0.9474
# Epoch 124/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9554 - val_loss: 0.1892 - val_accuracy: 0.9737
# Epoch 125/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9732 - val_loss: 0.1972 - val_accuracy: 0.9737
# Epoch 126/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9732 - val_loss: 0.2017 - val_accuracy: 0.9474
# Epoch 127/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1598 - accuracy: 0.9643 - val_loss: 0.1846 - val_accuracy: 0.9737
# Epoch 128/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1601 - accuracy: 0.9732 - val_loss: 0.2000 - val_accuracy: 0.9474
# Epoch 129/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9732 - val_loss: 0.1845 - val_accuracy: 0.9737
# Epoch 130/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9554 - val_loss: 0.1795 - val_accuracy: 0.9737
# Epoch 131/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9643 - val_loss: 0.1741 - val_accuracy: 0.9737
# Epoch 132/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9821 - val_loss: 0.1979 - val_accuracy: 0.9474
# Epoch 133/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1565 - accuracy: 0.9732 - val_loss: 0.1893 - val_accuracy: 0.9737
# Epoch 134/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1501 - accuracy: 0.9732 - val_loss: 0.1949 - val_accuracy: 0.9474
# Epoch 135/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9732 - val_loss: 0.1711 - val_accuracy: 1.0000
# Epoch 136/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1509 - accuracy: 0.9732 - val_loss: 0.1698 - val_accuracy: 0.9737
# Epoch 137/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.9732 - val_loss: 0.1711 - val_accuracy: 0.9474
# Epoch 138/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9821 - val_loss: 0.1792 - val_accuracy: 0.9737
# Epoch 139/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9643 - val_loss: 0.1971 - val_accuracy: 0.9474
# Epoch 140/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1567 - accuracy: 0.9554 - val_loss: 0.1988 - val_accuracy: 0.9474
# Epoch 141/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9732 - val_loss: 0.1970 - val_accuracy: 0.9474
# Epoch 142/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9554 - val_loss: 0.2312 - val_accuracy: 0.8947
# Epoch 143/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1520 - accuracy: 0.9732 - val_loss: 0.1831 - val_accuracy: 0.9737
# Epoch 144/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9554 - val_loss: 0.2273 - val_accuracy: 0.8947
# Epoch 145/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9643 - val_loss: 0.1631 - val_accuracy: 0.9737
# Epoch 146/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9821 - val_loss: 0.2185 - val_accuracy: 0.8947
# Epoch 147/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9732 - val_loss: 0.1655 - val_accuracy: 0.9737
# Epoch 148/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9643 - val_loss: 0.1797 - val_accuracy: 0.9737
# Epoch 149/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1426 - accuracy: 0.9732 - val_loss: 0.1703 - val_accuracy: 0.9737
# Epoch 150/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1384 - accuracy: 0.9732 - val_loss: 0.2004 - val_accuracy: 0.9474
# Epoch 151/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9732 - val_loss: 0.1593 - val_accuracy: 1.0000
# Epoch 152/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9643 - val_loss: 0.1603 - val_accuracy: 0.9737
# Epoch 153/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.9732 - val_loss: 0.1912 - val_accuracy: 0.9474
# Epoch 154/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9464 - val_loss: 0.1678 - val_accuracy: 0.9737
# Epoch 155/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1432 - accuracy: 0.9643 - val_loss: 0.1625 - val_accuracy: 0.9737
# Epoch 156/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9732 - val_loss: 0.1627 - val_accuracy: 0.9737
# Epoch 157/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1415 - accuracy: 0.9643 - val_loss: 0.1672 - val_accuracy: 0.9737
# Epoch 158/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.9732 - val_loss: 0.1589 - val_accuracy: 0.9737
# Epoch 159/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1368 - accuracy: 0.9732 - val_loss: 0.1712 - val_accuracy: 0.9737
# Epoch 160/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9821 - val_loss: 0.1698 - val_accuracy: 0.9737
# Epoch 161/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9643 - val_loss: 0.2084 - val_accuracy: 0.8947
# Epoch 162/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9643 - val_loss: 0.1609 - val_accuracy: 0.9737
# Epoch 163/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9643 - val_loss: 0.1554 - val_accuracy: 0.9737
# Epoch 164/250
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9732 - val_loss: 0.1628 - val_accuracy: 0.9737
# Epoch 165/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1348 - accuracy: 0.9732 - val_loss: 0.1512 - val_accuracy: 1.0000
# Epoch 166/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9286 - val_loss: 0.1821 - val_accuracy: 0.9474
# Epoch 167/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9732 - val_loss: 0.1914 - val_accuracy: 0.9474
# Epoch 168/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9732 - val_loss: 0.1635 - val_accuracy: 0.9737
# Epoch 169/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9643 - val_loss: 0.1704 - val_accuracy: 0.9737
# Epoch 170/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9732 - val_loss: 0.1567 - val_accuracy: 0.9737
# Epoch 171/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9821 - val_loss: 0.1900 - val_accuracy: 0.9474
# Epoch 172/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9732 - val_loss: 0.1528 - val_accuracy: 0.9737
# Epoch 173/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9554 - val_loss: 0.1688 - val_accuracy: 0.9737
# Epoch 174/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9643 - val_loss: 0.1476 - val_accuracy: 0.9737
# Epoch 175/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.9643 - val_loss: 0.1511 - val_accuracy: 0.9737
# Epoch 176/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9643 - val_loss: 0.1636 - val_accuracy: 0.9737
# Epoch 177/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 0.9732 - val_loss: 0.1602 - val_accuracy: 0.9737
# Epoch 178/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1400 - accuracy: 0.9643 - val_loss: 0.1507 - val_accuracy: 0.9737
# Epoch 179/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1256 - accuracy: 0.9732 - val_loss: 0.1548 - val_accuracy: 0.9737
# Epoch 180/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1264 - accuracy: 0.9732 - val_loss: 0.1427 - val_accuracy: 0.9737
# Epoch 181/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1211 - accuracy: 0.9821 - val_loss: 0.2027 - val_accuracy: 0.8947
# Epoch 182/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9643 - val_loss: 0.1761 - val_accuracy: 0.9474
# Epoch 183/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.9554 - val_loss: 0.1664 - val_accuracy: 0.9474
# Epoch 184/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9732 - val_loss: 0.1504 - val_accuracy: 0.9737
# Epoch 185/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9732 - val_loss: 0.1407 - val_accuracy: 0.9737
# Epoch 186/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1463 - accuracy: 0.9464 - val_loss: 0.1655 - val_accuracy: 0.9474
# Epoch 187/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1290 - accuracy: 0.9554 - val_loss: 0.1542 - val_accuracy: 0.9737
# Epoch 188/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9732 - val_loss: 0.1520 - val_accuracy: 0.9737
# Epoch 189/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9732 - val_loss: 0.1386 - val_accuracy: 1.0000
# Epoch 190/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9732 - val_loss: 0.1396 - val_accuracy: 0.9737
# Epoch 191/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.9643 - val_loss: 0.1750 - val_accuracy: 0.9474
# Epoch 192/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9821 - val_loss: 0.1687 - val_accuracy: 0.9474
# Epoch 193/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9732 - val_loss: 0.1424 - val_accuracy: 0.9737
# Epoch 194/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1281 - accuracy: 0.9732 - val_loss: 0.1784 - val_accuracy: 0.9474
# Epoch 195/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.9643 - val_loss: 0.1363 - val_accuracy: 1.0000
# Epoch 196/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9732 - val_loss: 0.1641 - val_accuracy: 0.9474
# Epoch 197/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1223 - accuracy: 0.9732 - val_loss: 0.1576 - val_accuracy: 0.9737
# Epoch 198/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9732 - val_loss: 0.1445 - val_accuracy: 0.9737
# Epoch 199/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9732 - val_loss: 0.1538 - val_accuracy: 0.9737
# Epoch 200/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1214 - accuracy: 0.9732 - val_loss: 0.1354 - val_accuracy: 0.9737
# Epoch 201/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1203 - accuracy: 0.9821 - val_loss: 0.1365 - val_accuracy: 0.9737
# Epoch 202/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1198 - accuracy: 0.9643 - val_loss: 0.1480 - val_accuracy: 0.9737
# Epoch 203/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1287 - accuracy: 0.9643 - val_loss: 0.1665 - val_accuracy: 0.9474
# Epoch 204/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1238 - accuracy: 0.9732 - val_loss: 0.1340 - val_accuracy: 0.9737
# Epoch 205/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9732 - val_loss: 0.1395 - val_accuracy: 0.9737
# Epoch 206/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9732 - val_loss: 0.1408 - val_accuracy: 0.9737
# Epoch 207/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9732 - val_loss: 0.1438 - val_accuracy: 0.9737
# Epoch 208/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1168 - accuracy: 0.9732 - val_loss: 0.1654 - val_accuracy: 0.9474
# Epoch 209/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9732 - val_loss: 0.1393 - val_accuracy: 0.9737
# Epoch 210/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9643 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 211/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9732 - val_loss: 0.1312 - val_accuracy: 0.9737
# Epoch 212/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1259 - accuracy: 0.9732 - val_loss: 0.1399 - val_accuracy: 0.9737
# Epoch 213/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9732 - val_loss: 0.1386 - val_accuracy: 0.9737
# Epoch 214/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.9732 - val_loss: 0.1315 - val_accuracy: 0.9737
# Epoch 215/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1261 - accuracy: 0.9732 - val_loss: 0.1328 - val_accuracy: 0.9737
# Epoch 216/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9732 - val_loss: 0.1598 - val_accuracy: 0.9474
# Epoch 217/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9732 - val_loss: 0.1469 - val_accuracy: 0.9737
# Epoch 218/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9732 - val_loss: 0.1363 - val_accuracy: 0.9737
# Epoch 219/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9732 - val_loss: 0.1284 - val_accuracy: 0.9737
# Epoch 220/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9821 - val_loss: 0.1459 - val_accuracy: 0.9737
# Epoch 221/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9643 - val_loss: 0.1703 - val_accuracy: 0.9474
# Epoch 222/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9732 - val_loss: 0.1258 - val_accuracy: 1.0000
# Epoch 223/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9643 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 224/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1170 - accuracy: 0.9643 - val_loss: 0.1553 - val_accuracy: 0.9474
# Epoch 225/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9732 - val_loss: 0.1458 - val_accuracy: 0.9737
# Epoch 226/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.9732 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 227/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9732 - val_loss: 0.1352 - val_accuracy: 0.9737
# Epoch 228/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9732 - val_loss: 0.1266 - val_accuracy: 0.9737
# Epoch 229/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9732 - val_loss: 0.1411 - val_accuracy: 0.9737
# Epoch 230/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9732 - val_loss: 0.1375 - val_accuracy: 0.9737
# Epoch 231/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 0.9732 - val_loss: 0.1668 - val_accuracy: 0.9474
# Epoch 232/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9732 - val_loss: 0.1232 - val_accuracy: 1.0000
# Epoch 233/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9821 - val_loss: 0.1224 - val_accuracy: 1.0000
# Epoch 234/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9554 - val_loss: 0.1327 - val_accuracy: 0.9737
# Epoch 235/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9732 - val_loss: 0.1677 - val_accuracy: 0.9474
# Epoch 236/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9732 - val_loss: 0.1245 - val_accuracy: 0.9737
# Epoch 237/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9732 - val_loss: 0.1263 - val_accuracy: 0.9737
# Epoch 238/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9821 - val_loss: 0.1580 - val_accuracy: 0.9474
# Epoch 239/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1171 - accuracy: 0.9643 - val_loss: 0.1412 - val_accuracy: 0.9737
# Epoch 240/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9643 - val_loss: 0.1760 - val_accuracy: 0.9474
# Epoch 241/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1182 - accuracy: 0.9732 - val_loss: 0.1432 - val_accuracy: 0.9737
# Epoch 242/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9554 - val_loss: 0.1485 - val_accuracy: 0.9474
# Epoch 243/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9732 - val_loss: 0.1236 - val_accuracy: 0.9737
# Epoch 244/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 0.9732 - val_loss: 0.1230 - val_accuracy: 0.9737
# Epoch 245/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9732 - val_loss: 0.1210 - val_accuracy: 0.9737
# Epoch 246/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1177 - accuracy: 0.9643 - val_loss: 0.1413 - val_accuracy: 0.9737
# Epoch 247/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9732 - val_loss: 0.1249 - val_accuracy: 0.9737
# Epoch 248/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9732 - val_loss: 0.1446 - val_accuracy: 0.9737
# Epoch 249/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9732 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 250/250
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 0.1485 - val_accuracy: 0.9474

# %% [markdown]
# Nous allons maintenant lancer l'entraînement du modèle. On définit d'abord les données et labels d'entraînement (X_train et Y_train).
#
# Le "batch_size" correspond à la taille du paquet de données utilisé pour l'optimisation via SGD comme expliqué précédemment. Un batch size plus grand donne une meilleure approximation de l'optimisation mais rend les calculs plus complexes.
#
# L'argument "epoch" correspond à la durée de l'entraînement. Une époque correspond au nombre d'optimisations nécessaires pour voir chaque donnée au moins une fois. Une interprétation possible est la suivante: à chaque fois, le réseau retire un "batch" de données sans remise, et optimise ses poids. Il continue ainsi jusqu'à ce que le jeu de données soit vide: cela correspond à une époque. Mettre 250 époques veut dire que l'algorithme se répète 250 fois. Le nombre d'itérations dans une époque est proportionnel au batch size: il y a 112 données dans le jeu d'entraînement (75\% de 150), donc il y a $\frac{112}{16}=7$ itérations d'optimisation par époque.

# %%
print("Final train accuracy is: "+str(model_history.history["accuracy"][-1]))
print("Final test accuracy is: "+str(model_history.history["val_accuracy"][-1]))
# Out:
# Final train accuracy is: 0.9642857313156128
# Final test accuracy is: 0.9736841917037964

# %% [markdown]
# On voit que notre modèle se débrouille plutôt bien: on devrait obtenir entre 0.94 et 1 de précision sur le jeu d'entraînement et de validation ! Notez que si vous relancez l'entraînement plusieurs fois vous risquez d'avoir des résultats différents: c'est normal. Il y a plusieurs aspects aléatoires dans notre démarche: d'une part, les poids du réseau sont initialisés aléatoirement à chaque fois, donc les conditions initiales sont différentes à chaque fois. De plus, comme expliqué précédemment, l'algorithme d'optimisation SGD fait en sorte que les "batch" de données sont pris aléatoirement, ce qui fait que les poids ne sont jamais vraiment mis à jour de la même manière à chaque fois.

# %%
t = range(250)

plt.plot(t,model_history.history["accuracy"],'r', label='train', linewidth=1.5)
plt.plot(t,model_history.history["val_accuracy"],'b', label='test', linewidth=1.5)
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()
plt.clf()

plt.plot(t,model_history.history["loss"],'r', label='train', linewidth=1.5)
plt.plot(t,model_history.history["val_loss"],'b', label='test', linewidth=1.5)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()
plt.clf()

# %% [markdown]
# On affiche ici la précision et la fonction de perte (loss) au cours de l'apprentissage, pour le jeu d'entraînement et de validation. Cela est utile pour observer l'évolution des performances au cours du temps, notamment à partir de quand on peut considérer que l'algorithme a convergé, ou s'il faut laisser plus d'époques ou mettre un learning rate plus ou moins élevé. Ici, on arrive rapidement à convergence en moins de 200 époques.
